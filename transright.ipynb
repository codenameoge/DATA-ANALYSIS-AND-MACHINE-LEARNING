# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Load data from a CSV file
df = pd.read_csv('replication.csv')

# %%
df.head()
# Out:
#   country_name country_text_id  country_id    year  v2x_polyarchy  \
# 0       Mexico             MEX         3.0  1999.0          0.605
# 1       Mexico             MEX         3.0  2000.0          0.667
# 2       Mexico             MEX         3.0  2001.0          0.684
# 3       Mexico             MEX         3.0  2002.0          0.694
# 4       Mexico             MEX         3.0  2003.0          0.702
#
#             v2x_regime  e_boix_regime  e_polity2    e_regionpol  \
# 0  Electoral Democracy            0.0        6.0  Latin America
# 1  Electoral Democracy            1.0        8.0  Latin America
# 2  Electoral Democracy            1.0        8.0  Latin America
# 3  Electoral Democracy            1.0        8.0  Latin America
# 4  Electoral Democracy            1.0        8.0  Latin America
#
#                   e_regionpol_6C  ...  lgb_unions  lgb_jointadoption  \
# 0  L. American and the Caribbean  ...         NaN                NaN
# ...

# %%
df.describe()
# Out:
#         country_id         year  v2x_polyarchy  e_boix_regime    e_polity2  \
# count  3967.000000  3967.000000    3967.000000    3747.000000  3243.000000
# mean     97.805395  2010.016637       0.521095       0.561516     3.677767
# std      57.012623     6.634483       0.262746       0.496268     6.347588
# min       3.000000  1999.000000       0.015000       0.000000   -10.000000
# 25%      51.000000  2004.000000       0.284000       0.000000    -2.000000
# 50%      94.000000  2010.000000       0.524000       1.000000     6.000000
# 75%     144.000000  2016.000000       0.769000       1.000000     9.000000
# max     210.000000  2021.000000       0.924000       1.000000    10.000000
#
#           dir_crim     ind_crim          gmc        gmcpr      gmcphys  ...  \
# count  3781.000000  3759.000000  3759.000000  3759.000000  3759.000000  ...
# mean      0.061095     0.635009     0.232509     1.782921     1.759511  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3967 entries, 0 to 3966
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country_name              3967 non-null   object
#  1   country_text_id           3967 non-null   object
#  2   country_id                3967 non-null   float64
#  3   year                      3967 non-null   float64
#  4   v2x_polyarchy             3967 non-null   float64
#  5   v2x_regime                3967 non-null   object
#  6   e_boix_regime             3747 non-null   float64
#  7   e_polity2                 3243 non-null   float64
#  8   e_regionpol               3967 non-null   object
#  9   e_regionpol_6C            3967 non-null   object
#  10  dir_crim                  3781 non-null   float64
#  11  ind_crim                  3759 non-null   float64
#  12  gmc                       3759 non-null   float64
# ...

# %%
df.shape
# Out:
# (3967, 51)

# %% [markdown]
# OBSERVATRIONS
# I observed that there are missing values in the following;
#  32  lgb_legal                 173 non-null    float64
#  34  lgb_const                 173 non-null    float64
#  35  lgb_broad                 173 non-null    float64
#  36  lgb_employ                173 non-null    float64
#  37  lgb_hatecrime             173 non-null    float64
#  38  lgb_incitement            173 non-null    float64
#  39  lgb_banconv               173 non-null    float64
#  40  lgb_marriage              173 non-null    float64
#  41  lgb_unions                173 non-null    float64
#  42  lgb_jointadoption         173 non-null    float64
#  43  lgb_secondparentadoption  173 non-null    float64
#  44  lgb_score                 173 non-null    float64
#  45  lgb_percent               173 non-null    float64
#  46  no_dircrim                3781 non-null   float64
#  47  no_indcrim                3759 non-null   float64
#  48  nophys                    3759 non-null   float64
#  49  nopsych                   3759 non-null   float64
#  50  nodiv                     3759 non-null   float64
#  6   e_boix_regime             3747 non-null   float64
#  7   e_polity2                 3243 non-null   float64
#  10  dir_crim                  3781 non-null   float64
#  11  ind_crim                  3759 non-null   float64
#  12  gmc                       3759 non-null   float64
#  13  gmcpr                     3759 non-null   float64
#  14  gmcphys                   3759 non-null   float64
#  15  gmcpsych                  3759 non-null   float64
#  16  gmcdiv                    3759 non-null   float64
#  17  nb3g                      3781 non-null   float64
#  18  adp_general               3781 non-null   float64
#  19  adp_constitution          3781 non-null   float64
#  20  adp_employment            3781 non-null   float64
#  21  adp_education             3781 non-null   float64
#  22  adp_healthcare            3781 non-null   float64
#  23  adp_housing               3781 non-null   float64
#  24  trip_score                3781 non-null   float64
#  25  trip_percent              3781 non-null   float64
#  26  wb_gdppc                  3882 non-null   float64
#  27  lgdppc_wb                 3882 non-null   float64
#  28  religiosity_percent       3951 non-null   float64
#  29  relpc_rcs                 2929 non-null   float64
#  30  chrpc_rcs                 2929 non-null   float64
#  31  muspc_rcs                 2908 non-null   float64
#  32  nrepc_rcs                 2897 non-null   float64

# %% [markdown]
# HANDLING MISSING VALUES
# using only mean to handle the missing values

# %%
for column in df.columns[df.isnull().any()]:
    df[column].fillna(df[column].mean(), inplace=True)
print("\nDataframe after handling missing values:")
print(df)
# Out:
# Dataframe after handling missing values:
#      country_name country_text_id  country_id    year  v2x_polyarchy  \
# 0          Mexico             MEX         3.0  1999.0          0.605
# 1          Mexico             MEX         3.0  2000.0          0.667
# 2          Mexico             MEX         3.0  2001.0          0.684
# 3          Mexico             MEX         3.0  2002.0          0.694
# 4          Mexico             MEX         3.0  2003.0          0.702
# ...           ...             ...         ...     ...            ...
# 3962      Hungary             HUN       210.0  2017.0          0.561
# 3963      Hungary             HUN       210.0  2018.0          0.483
# 3964      Hungary             HUN       210.0  2019.0          0.466
# 3965      Hungary             HUN       210.0  2020.0          0.460
# 3966      Hungary             HUN       210.0  2021.0          0.455
#
#                v2x_regime  e_boix_regime  e_polity2            e_regionpol  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3967 entries, 0 to 3966
# Data columns (total 51 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country_name              3967 non-null   object
#  1   country_text_id           3967 non-null   object
#  2   country_id                3967 non-null   float64
#  3   year                      3967 non-null   float64
#  4   v2x_polyarchy             3967 non-null   float64
#  5   v2x_regime                3967 non-null   object
#  6   e_boix_regime             3967 non-null   float64
#  7   e_polity2                 3967 non-null   float64
#  8   e_regionpol               3967 non-null   object
#  9   e_regionpol_6C            3967 non-null   object
#  10  dir_crim                  3967 non-null   float64
#  11  ind_crim                  3967 non-null   float64
#  12  gmc                       3967 non-null   float64
# ...

# %% [markdown]
# OBSERVATIONS
# I observed that there are 5 categorical values in our dataset
# VISUALIZING IT USING COUNTPLOT

# %%
for column in df.select_dtypes(include='object').columns:
    plt.figure(figsize=(13,42))
    sns.countplot(data=df, y=column)
    plt.title(f'Count Plot for {column}')
    plt.show()
# Out:
# /home/ai-lab-002/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/ai-lab-002/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/ai-lab-002/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
OBSERVATIONS
HANDLING OUTLIERS,SKEWNESS,CORR,TRYOUT CLASSIFIERS AND REGRESSION MODE
